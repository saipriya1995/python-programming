# %%
from sklearn import linear_model

features = [[2],[1],[5],[10]]
labels = [27, 11, 75, 155]

clf = linear_model.LinearRegression()
clf=clf.fit(features,labels)

predicted = clf.predict([[8]])
print(predicted)
#In our program, we have take 8
# Out:
# [123.]

# %%
import pandas as pd
cars=pd.read_csv(r"C:\Users\home\Documents\cars.csv")
print(cars)
# Out:
#     sno    HP        MPG   VOL          SP         WT
# 0   1.0  49.0  53.700681  89.0  104.185353  28.762059
# 1   2.0  55.0  50.013401  92.0  105.461264  30.466833
# 2   3.0  55.0  50.013401  92.0  105.461264  30.193597
# 3   4.0  70.0  45.696322  92.0  113.461264  30.632114
# 4   6.0  53.0  50.504232  92.0  104.461264  29.889149
# ..  ...   ...        ...   ...         ...        ...
# 81  NaN   NaN        NaN   NaN         NaN        NaN
# 82  NaN   NaN        NaN   NaN         NaN        NaN
# 83  NaN   NaN        NaN   NaN         NaN        NaN
# 84  NaN   NaN        NaN   NaN         NaN        NaN
# 85  NaN   NaN        NaN   NaN         NaN        NaN
#
# [86 rows x 6 columns]

# %%
##for reading data through read.csv
import pandas as pd

#for plotiing of barplot,boxplot
import matplotlib.pyplot as plt


#for graphical representation
import seaborn as sns
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-cfc569cb2e1f> in <module>
#       7
#       8 #for graphical representation
# ----> 9 import seaborn as sns
#      10 import numpy as np
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
cars.head()
# Out:
#    sno    HP        MPG   VOL          SP         WT
# 0  1.0  49.0  53.700681  89.0  104.185353  28.762059
# 1  2.0  55.0  50.013401  92.0  105.461264  30.466833
# 2  3.0  55.0  50.013401  92.0  105.461264  30.193597
# 3  4.0  70.0  45.696322  92.0  113.461264  30.632114
# 4  6.0  53.0  50.504232  92.0  104.461264  29.889149

# %%
cars.columns
# Out:
# Index(['sno', 'HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
import seaborn as sns

# %%
sns.pairplot(cars.iloc[:,:])
# Out:
# C:\Users\home\Anaconda3\envs\envs\wireless\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\home\Anaconda3\envs\envs\wireless\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
cars.corr()
# Out:
#           sno        HP       MPG       VOL        SP        WT
# sno  1.000000  0.676084 -0.924532  0.485511  0.603418  0.479950
# HP   0.676084  1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.924532 -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.485511  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.603418  0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.479950  0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.pairplot(cars.iloc[1:4])

# %%
import statsmodels.formula.api as smf

# %%
import statsmodels.formula.api as smf

# %%
ml1=smf.ols("MPG ~ WT+ VOL+ SP+ HP", data=cars).fit()

# %%
ml1.params
# Out:
# Intercept    30.677336
# WT            0.400574
# VOL          -0.336051
# SP            0.395627
# HP           -0.205444
# dtype: float64

# %%
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     63.80
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           1.54e-23
# Time:                        16:03:58   Log-Likelihood:                -233.96
# No. Observations:                  81   AIC:                             477.9
# Df Residuals:                      76   BIC:                             489.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6773     14.900      2.059      0.043       1.001      60.354
# WT             0.4006      1.693      0.237      0.814      -2.972       3.773
# VOL           -0.3361      0.569     -0.591      0.556      -1.469       0.796
# SP             0.3956      0.158      2.500      0.015       0.080       0.711
# HP            -0.2054      0.039     -5.239      0.000      -0.284      -0.127
# ==============================================================================
# Omnibus:                       10.780   Durbin-Watson:                   1.403
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.722
# Skew:                           0.707   Prob(JB):                      0.00285
# Kurtosis:                       4.215   Cond. No.                     6.09e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
m1_w= smf.ols("MPG ~ VOL", data = cars).fit()

# %%
m2_w=smf.ols("MPG ~ WT", data = cars).fit()

# %%
m3_w=smf.ols("MPG ~ VOL+WT", data = cars).fit()

# %%
m3_w.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     15.33
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           2.43e-06
# Time:                        16:13:22   Log-Likelihood:                -280.16
# No. Observations:                  81   AIC:                             566.3
# Df Residuals:                      78   BIC:                             573.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     56.8847      4.534     12.546      0.000      47.858      65.912
# VOL           -0.6983      0.984     -0.710      0.480      -2.658       1.261
# WT             1.4349      2.929      0.490      0.626      -4.397       7.266
# ==============================================================================
# Omnibus:                        2.405   Durbin-Watson:                   0.591
# Prob(Omnibus):                  0.300   Jarque-Bera (JB):                1.712
# Skew:                          -0.251   Prob(JB):                        0.425
# Kurtosis:                       3.506   Cond. No.                         597.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(ml1)

# %%
car_new=cars.drop(cars.index[[76,70,78]],axis = 0,inplace = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-35851354df7f> in <module>
# ----> 1 sm.graphics.influence_plot(ml2)
#
# NameError: name 'ml2' is not defined

# %%
m1_new= smf.ols("MPG ~ VOL+HP+SP+WT", data = car_new).fit()

# %%
m1_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     97.84
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           1.49e-28
# Time:                        16:17:52   Log-Likelihood:                -210.68
# No. Observations:                  78   AIC:                             431.4
# Df Residuals:                      73   BIC:                             443.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     19.1903     12.683      1.513      0.135      -6.087      44.467
# VOL           -0.2811      0.476     -0.590      0.557      -1.230       0.668
# HP            -0.2588      0.034     -7.619      0.000      -0.327      -0.191
# SP             0.4944      0.135      3.668      0.000       0.226       0.763
# WT             0.3953      1.423      0.278      0.782      -2.440       3.230
# ==============================================================================
# Omnibus:                       13.155   Durbin-Watson:                   1.183
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.126
# Skew:                           0.917   Prob(JB):                     0.000856
# Kurtosis:                       3.991   Cond. No.                     5.98e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sm.graphics.influence_plot(ml1)

# %%
print(m1_new.conf_int(0.05))
# Out:
#                   0          1
# Intercept -6.086859  44.467377
# VOL       -1.230470   0.668349
# HP        -0.326554  -0.191135
# SP         0.225795   0.763004
# WT        -2.439839   3.230491

# %%
mpg_pred = m1_new.predict(car_new)

# %%
car_new['pv'] = car_new['pv'] =mpg_pred

# %%
car_new['pv']
# Out:
# 0     44.372084
# 1     43.280588
# 2     43.172570
# 3     43.418458
# 4     43.075503
#         ...
# 81          NaN
# 82          NaN
# 83          NaN
# 84          NaN
# 85          NaN
# Name: pv, Length: 83, dtype: float64

# %%
cars['P'] = cars['p'] = mpg_pred

# %%
cars.head()
# Out:
#    sno    HP        MPG   VOL          SP         WT          P          p
# 0  1.0  49.0  53.700681  89.0  104.185353  28.762059  44.372084  44.372084
# 1  2.0  55.0  50.013401  92.0  105.461264  30.466833  43.280588  43.280588
# 2  3.0  55.0  50.013401  92.0  105.461264  30.193597  43.172570  43.172570
# 3  4.0  70.0  45.696322  92.0  113.461264  30.632114  43.418458  43.418458
# 4  6.0  53.0  50.504232  92.0  104.461264  29.889149  43.075503  43.075503

# %%
rsq_hp = smf.ols("HP ~ WT+VOL+SP", data = cars).fit()
rsq_hp.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     63.80
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           1.54e-23
# Time:                        16:39:26   Log-Likelihood:                -233.96
# No. Observations:                  81   AIC:                             477.9
# Df Residuals:                      76   BIC:                             489.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6773     14.900      2.059      0.043       1.001      60.354
# WT             0.4006      1.693      0.237      0.814      -2.972       3.773
# VOL           -0.3361      0.569     -0.591      0.556      -1.469       0.796
# SP             0.3956      0.158      2.500      0.015       0.080       0.711
# HP            -0.2054      0.039     -5.239      0.000      -0.284      -0.127
# ==============================================================================
# Omnibus:                       10.780   Durbin-Watson:                   1.403
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.722
# Skew:                           0.707   Prob(JB):                      0.00285
# Kurtosis:                       4.215   Cond. No.                     6.09e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
rsq_hp = smf.ols("HP ~ WT+SP+VOL", data = cars).fit().rsquared

# %%
vif_hp = 1/(1-rsq_hp)

# %%
vif_hp
# Out:
# 19.92658897499852

# %%
rsq_sp = smf.ols("SP ~ WT+HP+VOL", data = cars).fit().rsquared

# %%
vif_sp = 1/(1-rsq_sp)
vif_sp
# Out:
# 20.007638783050126

# %%
rsq_vol = smf.ols("VOL ~ WT+SP+HP", data = cars).fit().rsquared

# %%
vif_vol = 1/(1-rsq_vol)
vif_vol
# Out:
# 638.8060836592878

# %%
d1 = {'var':['hp','wt','sp','vol'], 'vif':[vif_hp,vif_wt,vif_sp,vif_vol]}
type(d1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-64bcadba45a3> in <module>
# ----> 1 d1 = {'var':['hp','wt','sp','vol'], 'vif':[vif_hp,vif_wt,vif_sp,vif_vol]}
#       2 type(d1)
#
# NameError: name 'vif_wt' is not defined

# %%
vif_frame = pd.DataFrame(d1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-9ccd0dc66f3a> in <module>
# ----> 1 vif_frame = pd.DataFrame(d1)
#
# NameError: name 'd1' is not defined
